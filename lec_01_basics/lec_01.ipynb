# %%
print('hello, world')
# Out:
# hello, world

# %% [markdown]
# # Лабораторная работа №0
# $$x_1 = x_0 + y$$
#
# ```javascript
# qwe = 5;
# ```

# %%
2 - 2
# Out:
# 4

# %%
a = 5
print(id(a))
a = 7
print(id(a))
a = [2, 3]
print(id(a))
a.append(4)
print(id(a))
# Out:
# 10914624
# 10914688
# 139825338368904
# 139825338368904

# %%
10 ** 1000 * 3
# Out:
# ...

# %%
3 / 4.
# Out:
# 0.75

# %%
s = 'per aspera \" ad\' a \n\t stra'
print(s)
# Out:
# per aspera " ad' a
# 	 stra

# %%
f_name = "Vasya"
l_name = "Vasiliev"

str = f_name + " " + l_name + " учится в универе"
a = 4.5555555555
str_1 = "{} {} {:0.2f} учится в универе".format(f_name, l_name, a)
print(str, str_1)
# Out:
# Vasya Vasiliev учится в универе Vasya Vasiliev 4.56 учится в универе

# %%
dir("asd")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
str = "per aspera ad astra"
print(str.find("ad"))
print(str.split(" "))
lst = ["1", "2", "3", "4", "5"]
print("!#!".join(lst))
# Out:
# 11
# ['per', 'aspera', 'ad', 'astra']
# 1!#!2!#!3!#!4!#!5

# %%
help("".isalnum)
# Out:
# Help on built-in function isalnum:
#
# isalnum(...) method of builtins.str instance
#     S.isalnum() -> bool
#
#     Return True if all characters in S are alphanumeric
#     and there is at least one character in S, False otherwise.

# %%
def my_sum(a, b = 6):
    '''
    returns sum of numbers with magic
    '''
    return a + b

print(my_sum(5, 7))
help(my_sum)
# Out:
# 12
# Help on function my_sum in module __main__:
#
# my_sum(a, b=6)
#     returns sum of numbers with magic

# %%
PEP8

# %%
print("!".isalnum())
# Out:
# False

# %%
# help("qwe".rstrip)
# Out:
# Help on built-in function rstrip:
#
# rstrip(...) method of builtins.str instance
#     S.rstrip([chars]) -> str
#
#     Return a copy of the string S with trailing whitespace removed.
#     If chars is given and not None, remove characters in chars instead.

# %%
# входит ли а в диапазон от -2 до 3
a = -1
if -2 < a < 3:
    print('perfect value')
elif a < -10: 
    print('small value')
else:
    print('normal value')
# Out:
# perfect value

# %%
def do_magic(a):
    '''
    Make magic for all!!!!
    '''
    print(a)
    return a ** 2

do_magic(5)

def do_super_magic():
    pass


help(do_magic)
# Out:
# 5
# Help on function do_magic in module __main__:
#
# do_magic(a)
#     Make magic for all!!!!

# %%
a = [3, 1, -3, 4, 5]
a.sort()
a.append(6)
print(a)

b = list(range(5))
print(b)

for i in range(2, 10, 2):
    print(i ** 2)
    
b.reverse()
print(b)

for i in a:
    print('elem {}'.format(i))

#dir([])
# Out:
# [-3, 1, 3, 4, 5, 6]
# [0, 1, 2, 3, 4]
# 4
# 16
# 36
# 64
# [4, 3, 2, 1, 0]
# elem -3
# elem 1
# elem 3
# elem 4
# elem 5
# elem 6

# %%
a = []
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
d = {}
d['f_name'] = 'Vasya'
d['l_name'] = 'Ivanov'
print('f_name' in d)

if 'f_nameq' in d:
    print(d['f_name'])
else:
    print('not found')

print(d.get('f_name', 'key not fount in dictionary d'))
# Out:
# True
# not found
# Vasya

# %%
z = 1, 2, 3
a, b, c = z
print(a, b, c)
print(z)

a, b = 5, 6
print(a, b)
# Out:
# 1 2 3
# (1, 2, 3)
# 5 6

# %%
lst = list(range(10, 100, 10))

for index, i in enumerate(lst):
    print(index, i)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 5 60
# 6 70
# 7 80
# 8 90

# %%
print(d.get('f1_name', 'key not fount in dictionary d'))
#del d['f_name']
print(d)

a, b, c = 1, 2, 3
print(a, b, c)

for key, value in d.items():
    print("key: {}".format(key), "value: {}".format(value))

for key in d.values():
    print(key)
    
k = d.keys()
print(k)
# Out:
# key not fount in dictionary d
# {'f_name': 'Vasya', 'l_name': 'Ivanov'}
# 1 2 3
# key: f_name value: Vasya
# key: l_name value: Ivanov
# Vasya
# Ivanov
# dict_keys(['f_name', 'l_name'])
# 5

# %%
b = -1
a = 5 if b < 0 else 6
print(a)
# Out:
# 5

# %%
a = list(range(10, 100, 10))
print(a)

for i, elem in enumerate(a):
    print(i, elem)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 5 60
# 6 70
# 7 80
# 8 90
